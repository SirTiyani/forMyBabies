# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ## PANDAS Cheatsheet

# %% [markdown]
# [readFile](#Importing-Data) | [export2API](#Exporting-Data) | [lookInside](#Inspecting-Data) | [selectData](#Data-Selection) | [plotData](#Plotting-Data)

# %% [markdown]
# [cleanData](#Clean-Data) | [filterData](#filter-Data) | [sortData](#sort-Data) | [groupData](#Group-Data) | [stats](#Statistics)
#
# <br>

# %% [markdown]
# ## Importing Data
#
#
# - #### From a CSV file
# ```python
# pd.read_csv(filename)```
#
# - #### From a delimited text file (like TSV)
# ```python
# pd.read_table(filename)
# ```
# - #### From an Excel file
# ```python
# pd.read_excel(filename)
# ```
# - #### Read from a SQL table/database
# ```python
# pd.read_sql(query, connection_object)
# ```
# - #### Read from a JSON formatted string, URL or file.
# ```python
# pd.read_json(json_string)
# ```
# - #### Parses an html URL, string or file and extracts tables to a list of dataframes
# ```python
# pd.read_html(url)
# ```
# - #### From a dict, keys for columns names, values for data as lists
# ```python
# pd.DataFrame(dict)
# ```

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Pokemon.csv', index_col=0)

# %% [markdown]
# <br>
#
# ### Exporting Data
#
# - #### Write to a CSV file
# ```python
# df.to_csv(filename)
# ```
# - #### Write to an Excel file
# ```python
# df.to_excel(filename)
# ```
# - #### Write to a SQL table
# ```python
# df.to_sql(table_name, connection_object)
# ```
# - #### Write to a file in JSON format
# ```python
# df.to_json(filename)
# ```
#
# [HOME](#PANDAS-Cheatsheet)
#
# <br>

# %% [markdown]
# ### Inspecting Data
#
# - #### First n rows of the DataFrame
# ```python
# df.head(n)
# ```
#
# - #### Last n rows of the DataFrame
# ```python
# df.tail(n)
# ```
#
# - #### Number of rows and columns
# ```python
# df.shape()
# ```
#
# - #### Index, Datatype and Memory information
# ```python
# df.info()
# ```
#
# - #### Summary statistics for numerical columns
# ```python
# df.describe()
# ```
#
# - #### View unique values and counts
# ```python
# s.value_counts(dropna=False)
# ```
#
# - #### Unique values and counts for all columns
# ```python
# df.apply(pd.Series.value_counts)
# ```
#
# [HOME](#PANDAS-Cheatsheet)
#
# <br>

# %%
print('Header')
df.head(10)
# Out:
# Header
#           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1    Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2      Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3     Venusaur  Grass  Poison    525  80      82       83      100      100
# 4   Charmander   Fire     NaN    309  39      52       43       60       50
# 5   Charmeleon   Fire     NaN    405  58      64       58       80       65
# 6    Charizard   Fire  Flying    534  78      84       78      109       85
# 7     Squirtle  Water     NaN    314  44      48       65       50       64
# 8    Wartortle  Water     NaN    405  59      63       80       65       80
# 9    Blastoise  Water     NaN    530  79      83      100       85      105
# 10    Caterpie    Bug     NaN    195  45      30       35       20       20
#
#     Speed  Stage Legendary
# 1      45      1     False
# 2      60      2     False
# 3      80      3     False
# 4      65      1     False
# 5      80      2     False
# 6     100      3     False
# 7      43      1     False
# 8      58      2     False
# 9      78      3     False
# 10     45      1     False

# %%
print('Information\n')
print(df.info())
print('\nShape\n')
# Out:
# Information
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
# Name         151 non-null object
# Type 1       151 non-null object
# Type 2       67 non-null object
# Total        151 non-null int64
# HP           151 non-null int64
# Attack       151 non-null int64
# Defense      151 non-null int64
# Sp. Atk      151 non-null int64
# Sp. Def      151 non-null int64
# Speed        151 non-null int64
# Stage        151 non-null int64
# Legendary    151 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB
# None
#
# Shape

# %% [markdown]
# <br>
#
# ## Data Selection

# %% [markdown]
# #### - Returns column with label col as Series
# ```python
# df[col]
# ```
# #### - Returns columns as a new DataFrame
# ```python
# df[[col1, col2]]
# ```
# #### - Selection by position
# ```python
# s.iloc[0]
# ```
# #### - Selection by index
# ```python
# s.loc['index_one']
# ```
# #### - First row
# ```python
# df.iloc[0,:]
# ```
# #### - First element of first column
# ```python
# df.iloc[0,0]
# ```
#
# [HOME](#PANDAS-Cheatsheet)
#
# <br>

# %% [markdown]
# ## Plotting Data
#
# <br>
#
# - ### Line plot of single column
#
# ```python
# sns.set_style("ticks")
#
# plt.figure(figsize=(x, y)
# sns.set_style("darkgrid")
# plt.plot(df.dataColumn)
# plt.xlim(0, None)
# plt.ylim(0, None
# ```

# %%
print('\nLine Plots with Seaborn\n')

plt.figure(figsize=(10,6))
sns.set_style("ticks")
plt.plot(df.Attack)
plt.xlabel('Index'); plt.ylabel('Attack')
plt.xlim(0, None), plt.ylim(0, None);
# Out:
# Line Plots with Seaborn

# %% [markdown]
# [HOME](#PANDAS-Cheatsheet)
# <br>
#
# - ### From DataFrame
#
# ```python
# sns.set_style('whitegrid')
#
# sns.lmplot(
#             x='column1',
#             y='column2',
#             data=df,
#             aspect=2,
#             size=heigh
#           )
# ```

# %%
#fig, ax = plt.subplots(size=(10,7))
sns.set_style('whitegrid')
sns.lmplot(x='Attack', y='Defense', data=df, aspect=2, size=6, hue='Stage')
plt.xlim(0, None), plt.ylim(0, None);

# %% [markdown]
# [HOME](#PANDAS-Cheatsheet)
# <br>
#
# - ### Removing the Fit
#
# ```python
# sns.set_style('darkgrid')
#
# sns.lmplot(
#             x='col1',
#             y='col2', data=df,
#             fit_reg=False,                   # No regression line
#             hue='col'                        # Legend
#           )
# ```

# %%
sns.set_style('darkgrid')
sns.lmplot(x='Attack', y='Defense', data=df,
           fit_reg=False, # No regression line
           hue='Stage',   # Color by evolution stage
           aspect=2,
           size=6)
plt.xlim(0, None), plt.ylim(0, None);

# %% [markdown]
# [HOME](#PANDAS-Cheatsheet)
#
# <br>
#
# - ### Setting Color Palettes
# generate random colors later
#
#   ```python
#   type_colors = ['#78C850',  # Grass
#                  '#F08030',  # Fire
#                  '#6890F0',  # Water
#                  '#A8B820',  # Bug
#                  '#A8A878',  # Normal
#                  '#A040A0',  # Poison
#                  '#F8D030',  # Electric
#                  '#E0C068',  # Ground
#                  '#EE99AC',  # Fairy
#                  '#C03028',  # Fighting
#                  '#F85888',  # Psychic
#                  '#B8A038',  # Rock
#                  '#705898',  # Ghost
#                  '#98D8D8',  # Ice
#                  '#7038F8',  # Dragon
#                    ]
#   ```

# %%
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %% [markdown]
# [HOME](#PANDAS-Cheatsheet)
#
# <br>
#
# - ### Box Plots
#
# ```python
# relevent_df = df.drop(
#                         [labels],
#                         axis=1
#                      )
# sns.boxplot(data=relevent_df)
# ```

# %%
plt.figure(figsize=(8,5))
stats_df = df.drop(
                    ['Total', 'Stage', 'Legendary'],
                    axis=1
                  )
sns.boxplot(data=stats_df);

# %% [markdown]
# [HOME](#PANDAS-Cheatsheet)
#
# <br>
#
# - ### Histograms
#   - #### Distribution plots
#
#   ```python
#   sns.distplot(df.Column)
#   ```

# %%
plt.figure(figsize=(10,7))
sns.distplot(df.Attack);

# %% [markdown]
# [HOME](#PANDAS-Cheatsheet)
# <br>
#
#   - #### Bar Plot
#
#   ```
#   sns.countplot(
#                       x='col',
#                       data=df,
#                       palette=col_type_colors
#                  )
#
#   plt.xticks(rotation=angle)
#   ```

# %%
plt.figure(figsize=(10,7))

sns.countplot(
                  x='Type 1',
                  data=df,
                  palette=pkmn_type_colors
             )

plt.xticks(rotation=45);

# %% [markdown]
# [HOME](#PANDAS-Cheatsheet)
#
# <br>
#
# ### Clean Data

# %% [markdown]
# - #### Replace all values equal to 1 with 'one'
# ```python
# s.replace(1,'one')
# ```
# - #### Replace all 1 with 'one' and 3 with 'three'
# ```python
# s.replace([1,3],['one','three'])
# ```
# - #### 	Mass renaming of columns
# ```python
# df.rename(columns=lambda x: x + 1)
# ```
# - #### Selective renaming
# ```python
# df.rename(columns={'old_name': 'new_ name'})
# ```
# - #### Change the index
# ```python
# df.set_index('column_one')
# ```
# - #### Mass renaming of index
# ```python
# df.rename(index=lambda x: x + 1)
# ```
#
# - #### Rename columns
# ```python
# df.columns = ['a','b','c']
# ```
# - #### Checks for null Values, Returns Boolean Arrray
# ```python
# pd.isnull()
# ```
# - #### Opposite of pd.isnull()
# ```python
# pd.notnull()
# ```
# - #### Drop all rows that contain null values
# ```python
# df.dropna()
# ```
# - #### Drop all columns that contain null values
# ```python
# df.dropna(axis=1)
# ```
# - #### Drop all rows have have less than n non null values
# ```python
# df.dropna(axis=1,thresh=n)
# ```
# - #### Replace all null values with x
# ```python
# df.fillna(x)
# ```
# - #### Replace all null values with the mean
#     - mean can be replaced with almost any function from the statistics section
# ```python
# s.fillna(s.mean())
# ```
# - #### Convert the datatype of the series to float
# ```python
# s.astype(float)
# ```
#
# [HOME](#PANDAS-Cheatsheet)

# %% [markdown]
# ### Filter Data
#
# #### - Rows where the column col is greater than 0.5
# ```python
# df[df[col] > 0.5]
# ```
# #### - Rows where 0.7 > col > 0.5
# ```python
# df[(df[col] > 0.5) & (df[col] < 0.7)]
# ```
# #### - Create a pivot table that groups by col1 and calculates the mean of col2 and col3
# ```python
# df.pivot_table(index=col1,values=[col2,col3],aggfunc=mean)
# ```
# #### - Apply the function np.mean() across each column
# ```python
# df.apply(np.mean)
# ```
# #### - Apply the function np.max() across each row
# ```python
# df.apply(np.max,axis=1)
# ```
#
# [HOME](#PANDAS-Cheatsheet)
#
# <br>

# %% [markdown]
# ### Sort Data
#
# #### - Sort values by col1 in ascending order
# ```python
# df.sort_values(col1)
# ```
# #### - Sort values by col2 in descending order
# ```python
# df.sort_values(col2,ascending=False)
# ```
# #### - Sort values by col1 in ascending order then col2 in descending order
# ```python
# df.sort_values([col1,col2],ascending=[True,False])
# ```
#
# [HOME](#PANDAS-Cheatsheet)
#
# <br>

# %% [markdown]
# ### Group Data
#
# #### - Returns a groupby object for values from one column
# ```python
# df.groupby(col)
# ```
# #### - Returns groupby object for values from multiple columns
# ```python
# df.groupby([col1,col2])
# ```
# #### - Returns the mean of the values in col2, grouped by the values in col1
#     - mean can be replaced with almost any function from the statistics section
# ```python
# df.groupby(col1)[col2]
# ```
# #### - Find the average across all columns for every unique col1 group
# ```python
# df.groupby(col1).agg(np.mean)
# ```
#
# [HOME](#PANDAS-Cheatsheet)
#
# <br>

# %% [markdown]
# ## Statistics
#
# #### - Summary statistics for numerical columns
# ```python
# df.describe()
# ```
# #### - Returns the mean of all columns
# ```python
# df.mean()
# ```
# #### - Returns the correlation between columns in a DataFrame
# ```python
# df.corr()
# ```
# #### - Returns the number of non-null values in each DataFrame column
# ```python
# df.count()
# ```
# #### - Returns the highest value in each column
# ```python
# df.max()
# ```
# #### - Returns the lowest value in each column
# ```python
# df.min()
# ```
# #### - Returns the median of each column
# ```python
# df.median()
# ```
# #### - Returns the standard deviation of each column
# ```python
# df.std()
# ```
